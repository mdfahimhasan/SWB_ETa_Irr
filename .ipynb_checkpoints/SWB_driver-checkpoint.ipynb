# %% [markdown]
# # Author
#
# ### Md Fahim Hasan
# #### PhD Candidate
# #### Civil and Environmental Engineering
# #### Colorado State University

# %% [markdown]
# ---------

# %% [markdown]
# # Data format and units

# %% [markdown]
# ### Required Data Inputs and Units
# The following variables are required as daily inputs for the model, and must be formatted as described below:
#
# `DOY (Day of the Year):` Integer value representing the day of the year (1–365/366).
# `U (Wind Speed):` Horizontal wind speed measured over a grass surface at a height of 2 meters above the ground, in meters per second (m/s). This should be the mean daily value.
# `Ta (Air Temperature):` Mean daily air temperature in degrees Celsius (°C).
# `RH min (Minimum Relative Humidity):` Mean daily minimum relative humidity value in percentage (%).
# `ETo (Reference Evapotranspiration):` Grass reference evapotranspiration, in millimeters per day (mm/d).
# `Precip (Precipitation):` Daily precipitation in millimeters (mm). If no precipitation is applied on a given day, this value should be set to 0 or the code will do that automatically.
# `hc (Crop Canopy Height):` Crop canopy height, in meters (m). This is a critical input that varies throughout the season.
# `Irr (Irrigation Water Depth):` Depth of irrigation water applied, in millimeters (mm). If no irrigation is applied on a given day, this value should be set to 0 or the code will do that automatically.

# %% [markdown]
# --------------

# %%
import os
from SWB_utils import *
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# -----------

# %% [markdown]
# # SWB model run

# %% [markdown]
# ## Step 1: Assign crop growth stages

# %%
input_file = 'input_data.csv'  # Path to your input CSV data

emergence_day = '15-May-2005'
full_canopy_day = '09-Jul-2005'
Lin = 20  # Length of initial growth stage (source: Table 8.3-Hoffman 2007)
Lmid = 60  # Length of mid-season (source: Table 8.3-Hoffman 2007)

df1, Ldev_start_DOY, Ldev_end_DOY, Llate_start_DOY, Llate_end_DOY = decide_crop_growth_stage(
    input_csv_df=input_file, emergence_day=emergence_day, full_canopy_day=full_canopy_day, Lin=Lin, Lmid=Lmid)

# %% [markdown]
# ## Step 2: Calculate root zone depth (Rz)

# %%
Rz_ini = 0.15  # Initial root zone depth in meters
Rz_max = 0.7  # Maximum root zone depth in meters

df2 = calc_Rz(df1, Rz_ini=Rz_ini, Rz_max=Rz_max, doy_col='DOY')

# %% [markdown]
# ## Step 3: Calculate TAW, RAW, and dMAD

# %%
MAD_fraction = 0.5  # Value for allowable soil water depletion fraction
# source MAD data https://extension.umn.edu/irrigation/basics-irrigation-scheduling#table-4-recommended-allowable-soil-moisture-depletion-limits-for-crops-by-growth-stage-1847510

theta_fc_perc = 21.1  # Volumetric soil moisture at field capacity (%)
theta_wp_perc = 12.04  # Volumetric soil moisture at wilting point (%)

df3 = calc_TAW_RAW_dMAD(df2, MAD_fraction=MAD_fraction, theta_fc_perc=theta_fc_perc, theta_wp_perc=theta_wp_perc)

# %% [markdown]
# ## Step 4: Estimate Kcb values for the entire season

# %%
Kcb_ini = 0.15  # Initial crop coefficient for soybeans (source: Table 8.2-Hoffman 2007)
Kcb_mid = 1.1  # Mid-season crop coefficient (source: Table 8.2-Hoffman 2007)
Kcb_end = 0.3  # End-season crop coefficient (source: Table 8.2-Hoffman 2007)
target_climate = 'sub-humid'

df4, Kcb_ini_mod, Kcb_mid_mod, Kcb_end_mod = estimate_Kcb_all_season(
    df3, Kcb_ini=Kcb_ini, Kcb_mid=Kcb_mid, Kcb_end=Kcb_end,
    Ldev_start_DOY=Ldev_start_DOY, Ldev_end_DOY=Ldev_end_DOY,
    Llate_start_DOY=Llate_start_DOY, Llate_end_DOY=Llate_end_DOY,
    target_climate=target_climate)

# %% [markdown]
# ## Step 5: Estimate Kcmax values

# %%
df5 = estimate_Kcmax(df4, windS_col='U', minRH_col='RH min', canopyH_col='hc')

# %% [markdown]
# ## Step 6: Assign TEW and REW values based on soil type

# %%
# Selected TEW and REW values on the higher ends of the prescribed ranges
# Ze considered 0.1 m as sandy loam is coarse soil
TEW = 12  # Total evaporable water in mm (source: Table 8.5-Hoffman 2007)
REW = 7  # Readily evaporable water in mm (source: Table 8.5-Hoffman 2007)

df6 = assign_TEW_REW(df5, TEW=TEW, REW=REW)

# %% [markdown]
# ## Step 7: Estimate fraction of soil exposed and wetted (fc and few)

# %%
fw = 1  # considering Lateral Move (self-propelled) sprinkler (source: Table 8.6-Hoffman 2007)
df7 = estimate_few(df6, fw=fw, Kcmin=Kcb_ini_mod, canopyH_col='hc')

# %% [markdown]
# ## Step 8: Curate and reorder Precipitation and Irrigation data

# %%
df8 = curate_reorder_P_Irr_data(df7, precip_col='Precip', Irr_col='Irr')

# %% [markdown]
# ## Step 9: Run the daily water balance calculations

# %%
SWB_final_df = run_daily_water_balance(df8, output_csv='SWB_Irr_output.csv')
# Out:
# Running daily soil water balance...
# Daily soil water balance run completed...

# %% [markdown]
# ------------

# %% [markdown]
# # SWB model outputs

# %%
# crop seasonal water use
total_ETa =  SWB_final_df['ETa'].sum()

# deep percolation
total_DP = SWB_final_df['DP'].sum()

# total irrigation
total_Irr = SWB_final_df['Irr'].sum()

# required irrigation amount


# soil evaporation
total_soil_E = SWB_final_df['KeETo'].sum()
total_soil_E_perc = total_soil_E * 100 / (total_Irr + SWB_final_df['Precip'].sum())

print(f'Crop seasonal water use= {total_ETa:.2f} mm')
print(f'Deep percolation for the season = {total_DP:.2f} mm')
print(f'Irrigation applied during the season = {total_Irr:.2f} mm')
print(f'Total soil evaporation = {total_soil_E:.2f} mm')
print(f'Soil evaporation as a percentage of total water applied (Irr + Precip) = {total_soil_E_perc:.2f} %')
# Out:
# Crop seasonal water use= 633.50 mm
# Deep percolation for the season = 169.14 mm
# Irrigation applied during the season = 686.00 mm
# Total soil evaporation = 120.75 mm
# Soil evaporation as a percentage of total water applied (Irr + Precip) = 15.47 %

# %% [markdown]
# ----------

# %% [markdown]
# # SWB model ouput plots

# %%
SWB_final_df = pd.read_csv('SWB_Irr_output.csv')

# %%
fig_dir = './figs'

if not os.path.exists(fig_dir):
    os.makedirs([fig_dir])

# %%
# Kcb vs DOY
plt.rcParams['font.size'] = 12

plt.figure(figsize=(10, 6))
plt.plot(SWB_final_df['DOY'], SWB_final_df['Kcb_daily'], label='Kcb', marker='o', markersize=0.2)

plt.xlabel('DOY')
plt.ylabel('Kcb')
plt.savefig('./figs/Kcb.png')

# %%
# Kcb, Ke, and Ks
plt.figure(figsize=(10, 6))

plt.plot(SWB_final_df['DOY'], SWB_final_df['Kcb_daily'], label='Kcb', marker='o', markersize=0.3)
plt.plot(SWB_final_df['DOY'], SWB_final_df['Ke'], label='Ke', marker='o', linestyle='--', markersize=0.2)
plt.plot(SWB_final_df['DOY'], SWB_final_df['Ks'], label='Ks', marker='o', linestyle='-.', markersize=0.2)

plt.xlabel('DOY')
plt.ylabel('Kcb, Ke, Ks')

plt.legend()
plt.savefig('./figs/all_coefs.png')

# %%
# Kco (Kcb*Ke + Ks) and Kcb
plt.figure(figsize=(10, 6))

plt.plot(SWB_final_df['DOY'], SWB_final_df['Kco'], label='Kco (= Kcb * Ke + Ks)', marker='o', markersize=0.2, linestyle='--', color='red')
plt.plot(SWB_final_df['DOY'], SWB_final_df['Kcb_daily'], label='Kcb', marker='o', markersize=0.2)

plt.xlabel('DOY')
plt.ylabel('Kco, Kcb')

plt.legend()
plt.savefig('./figs/Kcb_vs_Kco_comparison.png')

# %%
# ETa and ETo 
plt.figure(figsize=(10, 6))

plt.plot(SWB_final_df['DOY'], SWB_final_df['ETa'], label='ETa', marker='^', markersize=0.2, color='green')
plt.plot(SWB_final_df['DOY'], SWB_final_df['ETo'], label='ETo', marker='s', markersize=0.2, color='blue')

plt.xlabel('DOY')
plt.ylabel('ET (mm/d)')

plt.legend()
plt.savefig('./figs/ETref_ETa.png')

# %%
# SMD, dMAD, and irrigation applied by the farmer

fig, ax1 = plt.subplots(figsize=(10, 6))

# SMD
line1, = ax1.plot(SWB_final_df['DOY'], SWB_final_df['Di_start'], label='SMD', color='red')
ax1.set_xlabel('DOY')
ax1.set_ylabel('Soil Moisture Depletion (mm)', color='red')
ax1.tick_params(axis='y')
ax1.set_ylim([0, 50]) 

# dMAD
ax2 = ax1.twinx()
line2, = ax2.plot(SWB_final_df['DOY'], SWB_final_df['dMAD'], label='dMAD', color='blue', marker='o', markersize=0.5)
ax2.set_ylabel('dMAD (mm)', color='blue')
ax2.tick_params(axis='y')
ax2.set_ylim([0, 50])

# irrigation applied
positive_irr = SWB_final_df[SWB_final_df['Irr'] > 0]
line3 = ax1.scatter(positive_irr['DOY'], positive_irr['Irr'], color='green', marker='^', label='Irrigation applied')


lines = [line1, line2, line3]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left')
plt.savefig('./figs/deficit_vs_dMAD_actualIrr.png')

# %% [markdown]
# ---------

# %% [markdown]
# # Determining total 'required irrigation' for the season

# %%
# seasonal (total) irrigation “required"
# To do this analysis, the applied irrigation value has to be set to zero first for all occasions
# The only source of water would be Precipitation
# This way, the SWb will simulate total deficit in a condition when the crop water requirement is filled by precipitation and soil mositure storage
# At the end of model simulation, the total soil moisture deficit across dMAD, will be the irrigation required for the season

# # Step 1
input_df = pd.read_csv('input_data.csv')
input_df['Irr'] = 0

emergence_day = '15-May-2005'
full_canopy_day = '09-Jul-2005'
Lin = 20
Lmid = 60

df1, Ldev_start_DOY, Ldev_end_DOY, Llate_start_DOY, Llate_end_DOY = decide_crop_growth_stage(
    input_csv_df=input_df, emergence_day=emergence_day, full_canopy_day=full_canopy_day, Lin=Lin, Lmid=Lmid)


# # Step 2
Rz_ini = 0.15
Rz_max = 0.7

df2 = calc_Rz(df1, Rz_ini=Rz_ini, Rz_max=Rz_max, doy_col='DOY')

# # Step 3
MAD_fraction = 0.5  
theta_fc_perc = 21.1  
theta_wp_perc = 12.04 

df3 = calc_TAW_RAW_dMAD(df2, MAD_fraction=MAD_fraction, theta_fc_perc=theta_fc_perc, theta_wp_perc=theta_wp_perc)

# # Step 4
Kcb_ini = 0.15 
Kcb_mid = 1.1  
Kcb_end = 0.3  
target_climate = 'sub-humid'

df4, Kcb_ini_mod, Kcb_mid_mod, Kcb_end_mod = estimate_Kcb_all_season(
    df3, Kcb_ini=Kcb_ini, Kcb_mid=Kcb_mid, Kcb_end=Kcb_end,
    Ldev_start_DOY=Ldev_start_DOY, Ldev_end_DOY=Ldev_end_DOY,
    Llate_start_DOY=Llate_start_DOY, Llate_end_DOY=Llate_end_DOY,
    target_climate=target_climate)

# # Step 5
df5 = estimate_Kcmax(df4, windS_col='U', minRH_col='RH min', canopyH_col='hc')

# # Step 6
TEW = 12  
REW = 7  

df6 = assign_TEW_REW(df5, TEW=TEW, REW=REW)

# # Step 7
fw = 1  
df7 = estimate_few(df6, fw=fw, Kcmin=Kcb_ini_mod, canopyH_col='hc')

# # Step 8
df8 = curate_reorder_P_Irr_data(df7, precip_col='Precip', Irr_col='Irr')

# # Step 9
SWB_final_df = run_daily_water_balance(df8, output_csv='SWB_Irr_output_without_irrigation.csv')
# Out:
# Running daily soil water balance...
# Daily soil water balance run completed...

# %%
# Soil water eficit that has to be filled across the season by irrigation
sel_df = SWB_final_df[SWB_final_df['Di_start'] >= SWB_final_df['dMAD']]
Irr_required = sel_df['Di_start'].sum() - sel_df['dMAD'].sum()
print(f'Irrigation required during the season = {Irr_required:.2f} mm')
# Out:
# Irrigation required during the season = 2747.01 mm

# %%
# SMD and dMAD (without any irrigation applied)
fig, ax1 = plt.subplots(figsize=(10, 6))

# SMD
line1, = ax1.plot(SWB_final_df['DOY'], SWB_final_df['Di_start'], label='SMD', color='red')
ax1.set_xlabel('DOY')
ax1.set_ylabel('Soil Moisture Depletion (mm)', color='red')
ax1.tick_params(axis='y')
ax1.set_ylim([0, 100]) 

# dMAD
ax2 = ax1.twinx()
line2, = ax2.plot(SWB_final_df['DOY'], SWB_final_df['dMAD'], label='dMAD', color='blue', marker='o', markersize=0.5)
ax2.set_ylabel('dMAD (mm)', color='blue')
ax2.tick_params(axis='y')
ax2.set_ylim([0, 100])

plt.title('SMD and dMAD without irrigation applied')

lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left')
plt.savefig('./figs/deficit_vs_dMAD_without_Irr.png')
